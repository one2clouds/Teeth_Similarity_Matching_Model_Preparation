# %%
import numpy as np
import torch
import open3d as o3d
import json
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def load_data_from_json(filename):
    with open(filename, 'r') as f:
        data = json.load(f)
    
    # Convert feature vectors back to numpy arrays
    for entry in data:
        entry['feature_vector'] = np.array(entry['feature_vector'])
    
    return data

# %%
feature_data = feature_data = load_data_from_json('feature_info_client_data.json')

# %%
label_damaged = 15

# %%
feature_data[0]['label'] == label_damaged
# Out:
# False

# %%
label_damaged = '11'
int(label_damaged) == 11
# Out:
# True

# %%
def get_feature_data_of_selected_label_only(feature_data, label_damaged):
    data_json = []
    for i in range(len(feature_data)):
        print(feature_data[i]['label'])
        if int(feature_data[i]['label']) == int(label_damaged):
            data_json.append({
            "mesh_location": feature_data[i]['mesh_location'],
            "label": feature_data[i]['label'], 
            "feature_vector": feature_data[i]['feature_vector']
            })
        
    return data_json

# %%
my_json = get_feature_data_of_selected_label_only(feature_data, label_damaged)
# Out:
# 11
# 11
# 11
# 12
# 12
# 12
# 12
# 13
# 14
# 14
# 14
# 15
# 15
# 15
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 16
# 21
# 21
# 21
# 22
# 22
# 22
# 23
# 23
# 24
# 24
# 24
# 24
# 25
# 25
# 25
# 25
# 25
# 26
# 26
# 26
# 26
# 27
# 27
# 27
# 31
# 34
# 34
# 34
# 34
# 34
# 34
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 36
# 36
# 36
# 36
# 37
# 37
# 37
# 43
# 43
# 43
# 43
# 44
# 44
# 44
# 44
# 45
# 45
# 45
# 45
# 45
# 46
# 46
# 46
# 46
# 46
# 47
# 47
# 47

# %%
len(my_json)
# Out:
# 3

# %%
label_damaged
# Out:
# '11'

# %%
feature_data
# Out:
# [{'mesh_location': '/home/shirshak/STL_client_data/11/2024-07-05_00003-InoueYui-11Cr-11-crown_cad.stl',
#   'label': '11',
#   'feature_vector': array([-3.34496379e-01,  2.00438833e+00,  1.71739876e-01, -2.75462300e-01,
#          -2.48523146e-01,  1.83270299e+00,  3.34339094e+00,  1.61475703e-01,
#           5.55548370e-01,  5.54194212e-01, -3.34287375e-01, -3.81589413e-01,
#          -1.65720269e-01,  1.49684250e-01,  8.28199625e-01, -2.82488853e-01,
#           8.83672237e-01,  4.61961412e+00, -4.11129296e-01,  3.29566193e+00,
#          -1.39020875e-01,  1.02735460e+00,  3.46830249e-01,  1.34757984e+00,
#           7.12086380e-01,  1.03811614e-01, -5.99972546e-01, -2.08011076e-01,
#           1.05231953e+00,  1.04825997e+00, -4.06771392e-01, -8.12601671e-02,
#          -1.16429843e-01,  1.97577560e+00, -2.04887345e-01, -9.63098742e-03,
#           3.25887704e+00,  2.62501335e+00,  2.33891892e+00,  2.07230139e+00,
# ...
